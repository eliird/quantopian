# %%
import yfinance as yf
import datetime

# %%
# start = datetime.datetime.now() - datetime.timedelta(7)
# end = datetime.datetime.now()

start = '2020-01-01'
end = datetime.datetime.now()

df = yf.download('SPY, AMD', start=start, end=end, interval='1d')
df
# Out:
# [*********************100%***********************]  2 of 2 completed
# Price            Close                    High                     Low  \
# Ticker             AMD         SPY         AMD         SPY         AMD
# Date
# 2020-01-02   49.099998  301.194885   49.250000  301.213446   46.630001
# 2020-01-03   48.599998  298.914215   49.389999  300.054588   47.540001
# 2020-01-06   48.389999  300.054535   48.860001  300.137973   47.860001
# 2020-01-07   48.250000  299.210846   49.389999  299.961814   48.040001
# 2020-01-08   47.830002  300.805511   48.299999  302.038574   47.139999
# ...                ...         ...         ...         ...         ...
# 2024-12-16  126.690002  604.754578  127.760002  605.741308  123.120003
# 2024-12-17  125.019997  602.262939  127.080002  603.139992  123.150002
# 2024-12-18  121.410004  584.313416  127.750000  604.375836  120.430000
# 2024-12-19  118.879997  584.133972  123.379997  591.010851  118.449997
# ...

# %%
len(df)
# Out:
# 1252

# %%
df['Close']['AMD'].plot()
df['Close']['SPY'].plot()
# Out:
# <Axes: xlabel='Date'>
